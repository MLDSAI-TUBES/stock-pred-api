# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and prep the data

# %%
df = pd.read_csv('../cleaned_data/TLKM.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#             7 DAYS MA  7 DAYS STD DEV  14 DAYS MA  21 DAYS MA  dayofweek  \
# Date
# 2012-10-17  -1.901334       -1.101544   -1.927720   -1.944208   0.008923
# 2012-10-18  -1.895749       -1.125565   -1.920264   -1.939855   0.716706
# 2012-10-19  -1.895749       -1.125565   -1.916537   -1.936745   1.424489
# 2012-10-22  -1.895749       -1.125565   -1.911877   -1.933636  -1.406643
# 2012-10-23  -1.903195       -1.049270   -1.910945   -1.931770  -0.698860
#
#             quarter     month      year  dayofyear  dayofmonth  weekofyear  \
# Date
# 2012-10-17  1.34241  1.016593 -1.845348   1.033444    0.147246    1.030312
# 2012-10-18  1.34241  1.016593 -1.845348   1.042927    0.261864    1.030312
# 2012-10-19  1.34241  1.016593 -1.845348   1.052410    0.376483    1.030312
# 2012-10-22  1.34241  1.016593 -1.845348   1.080859    0.720337    1.096678
# 2012-10-23  1.34241  1.016593 -1.845348   1.090342    0.834955    1.096678
#
#                Close
# Date
# 2012-10-17 -1.884821
# 2012-10-18 -1.910838
# 2012-10-19 -1.910838
# 2012-10-22 -1.936855
# 2012-10-23 -1.910838

# %% [markdown]
# ### Split the dataset

# %%
train_len = int(len(df)*.8)
train_dataset = df[:train_len]
test_dataset = df[train_len:len(df)]

# %%
train_dataset_y = train_dataset[['Close']]

# %%
train_dataset.head()
# Out:
#             7 DAYS MA  7 DAYS STD DEV  14 DAYS MA  21 DAYS MA  dayofweek  \
# Date
# 2012-10-17  -1.901334       -1.101544   -1.927720   -1.944208   0.008923
# 2012-10-18  -1.895749       -1.125565   -1.920264   -1.939855   0.716706
# 2012-10-19  -1.895749       -1.125565   -1.916537   -1.936745   1.424489
# 2012-10-22  -1.895749       -1.125565   -1.911877   -1.933636  -1.406643
# 2012-10-23  -1.903195       -1.049270   -1.910945   -1.931770  -0.698860
#
#             quarter     month      year  dayofyear  dayofmonth  weekofyear  \
# Date
# 2012-10-17  1.34241  1.016593 -1.845348   1.033444    0.147246    1.030312
# 2012-10-18  1.34241  1.016593 -1.845348   1.042927    0.261864    1.030312
# 2012-10-19  1.34241  1.016593 -1.845348   1.052410    0.376483    1.030312
# 2012-10-22  1.34241  1.016593 -1.845348   1.080859    0.720337    1.096678
# 2012-10-23  1.34241  1.016593 -1.845348   1.090342    0.834955    1.096678
#
#                Close
# Date
# 2012-10-17 -1.884821
# 2012-10-18 -1.910838
# 2012-10-19 -1.910838
# 2012-10-22 -1.936855
# 2012-10-23 -1.910838

# %%
test_dataset.head()
# Out:
#             7 DAYS MA  7 DAYS STD DEV  14 DAYS MA  21 DAYS MA  dayofweek  \
# Date
# 2020-09-10  -0.668945       -0.239390   -0.605242   -0.574111   0.716706
# 2020-09-11  -0.706178        0.795896   -0.633201   -0.591525   1.424489
# 2020-09-14  -0.732240        0.456503   -0.650909   -0.601476  -1.406643
# 2020-09-15  -0.734102        0.411681   -0.659297   -0.603964  -0.698860
# 2020-09-16  -0.739687        0.377412   -0.677004   -0.611427   0.008923
#
#              quarter     month      year  dayofyear  dayofmonth  weekofyear  \
# Date
# 2020-09-10  0.449286  0.727164  0.956789   0.682575   -0.655081    0.698480
# 2020-09-11  0.449286  0.727164  0.956789   0.692058   -0.540462    0.698480
# 2020-09-14  0.449286  0.727164  0.956789   0.720507   -0.196608    0.764846
# 2020-09-15  0.449286  0.727164  0.956789   0.729990   -0.081990    0.764846
# 2020-09-16  0.449286  0.727164  0.956789   0.739473    0.032628    0.764846
#
#                Close
# Date
# 2020-09-10 -0.909183
# 2020-09-11 -0.766089
# 2020-09-14 -0.662021
# 2020-09-15 -0.740072
# 2020-09-16 -0.792106

# %% [markdown]
# ### Prep train set

# %%
hops = 60
no_cols = len(df.columns)-1
train_len = len(train_dataset)

# %%
X_train = []
y_train = []

for i in range(hops, train_len):
    X_train.append(train_dataset[i-60:i])
    y_train.append(train_dataset_y.iloc[i][0])
    
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (1907, 60, 12)

# %%
y_train.shape
# Out:
# (1907,)

# %% [markdown]
# #### Reshape the array into 3d

# %%
X_train_reshaped = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_train_reshaped.shape
# Out:
# (1907, 60, 12)

# %% [markdown]
# ## LSTM model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(60,12)))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            12600
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 32,851
# Trainable params: 32,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train_reshaped, y_train, epochs=150, batch_size=16)
# Out:
# Epoch 1/150
# 120/120 [==============================] - 4s 18ms/step - loss: 0.0874
# Epoch 2/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0365
# Epoch 3/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0329
# Epoch 4/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0288
# Epoch 5/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0261
# Epoch 6/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0250
# Epoch 7/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0234
# Epoch 8/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0223
# Epoch 9/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0216
# Epoch 10/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0220
# Epoch 11/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0205
# Epoch 12/150
# 120/120 [==============================] - 3s 21ms/step - loss: 0.0214
# Epoch 13/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0202
# Epoch 14/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0190
# Epoch 15/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0197
# Epoch 16/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0198
# Epoch 17/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0196
# Epoch 18/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0207
# Epoch 19/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0195
# Epoch 20/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0176
# Epoch 21/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0181
# Epoch 22/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0171
# Epoch 23/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0175
# Epoch 24/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0158
# Epoch 25/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0179
# Epoch 26/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0171
# Epoch 27/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0164
# Epoch 28/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0153
# Epoch 29/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0171
# Epoch 30/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0175
# Epoch 31/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0163
# Epoch 32/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0160
# Epoch 33/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0156
# Epoch 34/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0160
# Epoch 35/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0158
# Epoch 36/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0150
# Epoch 37/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0156
# Epoch 38/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0149
# Epoch 39/150
# 120/120 [==============================] - 3s 21ms/step - loss: 0.0159
# Epoch 40/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0151
# Epoch 41/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0151
# Epoch 42/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0150
# Epoch 43/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0148
# Epoch 44/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0149
# Epoch 45/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0155
# Epoch 46/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0146
# Epoch 47/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0134
# Epoch 48/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0143
# Epoch 49/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0152
# Epoch 50/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0153
# Epoch 51/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0143
# Epoch 52/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0139
# Epoch 53/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0146
# Epoch 54/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0124
# Epoch 55/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0146
# Epoch 56/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0134
# Epoch 57/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0131
# Epoch 58/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0132
# Epoch 59/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0138
# Epoch 60/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0132
# Epoch 61/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0133
# Epoch 62/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0135
# Epoch 63/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0138
# Epoch 64/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0126
# Epoch 65/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0138
# Epoch 66/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0125
# Epoch 67/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0127
# Epoch 68/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0139
# Epoch 69/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0126
# Epoch 70/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0126
# Epoch 71/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0130
# Epoch 72/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0120
# Epoch 73/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0126
# Epoch 74/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0125
# Epoch 75/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0122
# Epoch 76/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0134
# Epoch 77/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0121
# Epoch 78/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0126
# Epoch 79/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0123
# Epoch 80/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0121
# Epoch 81/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0130
# Epoch 82/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0122
# Epoch 83/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0114
# Epoch 84/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0122
# Epoch 85/150
# 120/120 [==============================] - 2s 21ms/step - loss: 0.0121
# Epoch 86/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0118
# Epoch 87/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0121
# Epoch 88/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0127
# Epoch 89/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0120
# Epoch 90/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0123
# Epoch 91/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0125
# Epoch 92/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0113
# Epoch 93/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0131
# Epoch 94/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0118
# Epoch 95/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0123
# Epoch 96/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0111
# Epoch 97/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0120
# Epoch 98/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0120
# Epoch 99/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0128
# Epoch 100/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0124
# Epoch 101/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0113
# Epoch 102/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0118
# Epoch 103/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0119
# Epoch 104/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0117
# Epoch 105/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0126
# Epoch 106/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0116
# Epoch 107/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0114
# Epoch 108/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0116
# Epoch 109/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0108
# Epoch 110/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0115
# Epoch 111/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0110
# Epoch 112/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0115
# Epoch 113/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0114
# Epoch 114/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0114
# Epoch 115/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0114
# Epoch 116/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0123
# Epoch 117/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0108
# Epoch 118/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0113
# Epoch 119/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0106
# Epoch 120/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0109
# Epoch 121/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0115
# Epoch 122/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0123
# Epoch 123/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0116
# Epoch 124/150
# 120/120 [==============================] - 2s 21ms/step - loss: 0.0118
# Epoch 125/150
# 120/120 [==============================] - 2s 21ms/step - loss: 0.0115
# Epoch 126/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0114
# Epoch 127/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0115
# Epoch 128/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0109
# Epoch 129/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0117
# Epoch 130/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0114
# Epoch 131/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0101
# Epoch 132/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0104
# Epoch 133/150
# 120/120 [==============================] - 2s 21ms/step - loss: 0.0114
# Epoch 134/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0106
# Epoch 135/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0103
# Epoch 136/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0103
# Epoch 137/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0113
# Epoch 138/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0108
# Epoch 139/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0108
# Epoch 140/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0113
# Epoch 141/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0108
# Epoch 142/150
# 120/120 [==============================] - 3s 22ms/step - loss: 0.0109
# Epoch 143/150
# 120/120 [==============================] - 3s 22ms/step - loss: 0.0116
# Epoch 144/150
# 120/120 [==============================] - 3s 21ms/step - loss: 0.0109
# Epoch 145/150
# 120/120 [==============================] - 3s 21ms/step - loss: 0.0115
# Epoch 146/150
# 120/120 [==============================] - 2s 21ms/step - loss: 0.0101
# Epoch 147/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0108
# Epoch 148/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0111
# Epoch 149/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0108
# Epoch 150/150
# 120/120 [==============================] - 2s 20ms/step - loss: 0.0106

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ## Predictions

# %% [markdown]
# ### prep test dataset

# %%
train_dataset_last60 = train_dataset.iloc[-60:]
test_dataset_full = test_dataset.copy()
test_dataset_full = pd.concat((train_dataset_last60, test_dataset_full), axis=0)

# %%
test_dataset_full.shape
# Out:
# (552, 12)

# %%
test_dataset_full_y = test_dataset_full[['Close']]

# %%
test_len = test_dataset_full.shape[0]

# %%
X_test = []
y_test = []

for i in range(hops, test_len):
    X_test.append(test_dataset_full[i-60:i])
    y_test.append(test_dataset_full_y.iloc[i][0])
    
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
X_test.shape
# Out:
# (492, 60, 12)

# %% [markdown]
# ### Predict

# %%
predictions = model.predict(X_test)
# Out:
# 16/16 [==============================] - 1s 8ms/step

# %%
actual_close = df[['Close']]
actual_close = pd.DataFrame(actual_close.iloc[train_len:, 0])

# %%
predictions = pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index = test_dataset.index
predictions['Actual'] = actual_close['Close']
predictions.rename(columns={0:'Pred'}, inplace=True)

# %%
predictions
# Out:
#                 Pred    Actual
# Date
# 2020-09-10 -0.668325 -0.909183
# 2020-09-11 -0.726411 -0.766089
# 2020-09-14 -0.675309 -0.662021
# 2020-09-15 -0.666431 -0.740072
# 2020-09-16 -0.653837 -0.792106
# ...              ...       ...
# 2022-09-12  1.320090  1.484382
# 2022-09-13  1.311830  1.458365
# 2022-09-14  1.296217  1.406331
# 2022-09-15  1.300278  1.432348
# 2022-09-16  1.326270  1.315272
#
# [492 rows x 2 columns]

# %%
predictions['Actual'].plot(figsize=(20,8), legend=True, color='blue')
predictions['Pred'].plot(legend=True, color='red', figsize=(20,8))
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# ### Evaluation

# %%
from joblib import load

close_scaler = load('../feature_engineering/tlkm_close_scaler.bin')

# %%
inversed_pred = close_scaler.inverse_transform(np.array(predictions['Pred']).reshape(-1,1))
inversed_act = close_scaler.inverse_transform(np.array(predictions['Actual']).reshape(-1,1))

# %%
inversed = pd.DataFrame(inversed_pred)
inversed['Actual'] = inversed_act
inversed.rename({0:'Pred'}, axis=1, inplace=True)
inversed.index = test_dataset.index
inversed.head(2)
# Out:
#                    Pred  Actual
# Date
# 2020-09-10  2885.154053  2700.0
# 2020-09-11  2840.501953  2810.0

# %%
def plotErrorHist(inversed_df):
    """
    Function to plot error histogram
    """
    error = inversed_df['Pred'] - inversed_df['Actual']
    # plt.hist(error, bins=25)
    sns.displot(error)
    plt.xlabel('Prediction Error [Close]')
    _ = plt.ylabel('Count')

# %%
plotErrorHist(inversed)

# %% [markdown]
# **RMSE**

# %%
from statsmodels.tools.eval_measures import rmse

rmse(inversed['Pred'], inversed['Actual'])
# Out:
# 151.55156699096477

# %% [markdown]
# **MAPE**

# %%
# mape
def mape(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

mape(inversed['Actual'], inversed['Pred'])
# Out:
# 3.1047642002103393

# %% [markdown]
# **R-squared**

# %%
from sklearn.metrics import r2_score

r2_score(inversed['Actual'], inversed['Pred'])
# Out:
# 0.9286778055674868
