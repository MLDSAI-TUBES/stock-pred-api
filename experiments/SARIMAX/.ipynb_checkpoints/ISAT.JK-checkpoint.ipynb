# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Shows plots in jupyter notebook
# %matplotlib inline

# Set plot style
sns.set(color_codes=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.10.0

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv('../cleaned_data/ISAT.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#             7 DAYS MA  7 DAYS STD DEV  14 DAYS MA  21 DAYS MA  dayofweek  \
# Date
# 2012-10-17   0.759710        0.242258    0.604458    0.595933   0.008923
# 2012-10-18   0.799685       -0.312385    0.635721    0.597431   0.716706
# 2012-10-19   0.808568       -0.297827    0.664751    0.597431   1.424489
# 2012-10-22   0.804127       -0.381060    0.700480    0.607911  -1.406643
# 2012-10-23   0.821893       -0.038690    0.736209    0.633364  -0.698860
#
#             quarter     month      year  dayofyear  dayofmonth  weekofyear  \
# Date
# 2012-10-17  1.34241  1.016593 -1.845348   1.033444    0.147246    1.030312
# 2012-10-18  1.34241  1.016593 -1.845348   1.042927    0.261864    1.030312
# 2012-10-19  1.34241  1.016593 -1.845348   1.052410    0.376483    1.030312
# 2012-10-22  1.34241  1.016593 -1.845348   1.080859    0.720337    1.096678
# 2012-10-23  1.34241  1.016593 -1.845348   1.090342    0.834955    1.096678
#
#                Close
# Date
# 2012-10-17  0.865115
# 2012-10-18  0.834181
# 2012-10-19  0.834181
# 2012-10-22  0.926983
# 2012-10-23  0.896049

# %% [markdown]
# ### Plot the Close price - our target

# %%
df['Close'].plot(figsize=(15,2))
plt.legend(['Close Price'])
plt.title('ISAT.JK Close Price')
# Out:
# Text(0.5, 1.0, 'ISAT.JK Close Price')

# %% [markdown]
# ### Split the data
# - Split the data into independent variables and target variable
# - Split the data into train and test set (80:20)

# %%
train_len = int(len(df)*.8)
train_dataset = df[:train_len]
test_dataset = df[train_len:len(df)]

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('Close')
test_labels = test_features.pop('Close')

# %% [markdown]
# ## Understanding Time Series Data

# %% [markdown]
# ### Decompose time series into Trend, Seasonality, and Random Noise

# %%
import statsmodels.api as sm

# %%
seas_d = sm.tsa.seasonal_decompose(df['Close'], model='additive', period=365)
fig = seas_d.plot()
plt.show()

# %% [markdown]
# ### ADF Test to check stationarity of the data

# %%
from statsmodels.tsa.stattools import adfuller
def test_adf(series, title=''):
    dfout={}
    dftest=sm.tsa.adfuller(series.dropna(), autolag='AIC', regression='ct')
    for key,val in dftest[4].items():
        dfout[f'critical value ({key})']=val
    if dftest[1]<=0.05:
        print("Strong evidence against Null Hypothesis")
        print("Reject Null Hypothesis - Data is Stationary")
        print("Data is Stationary", title)
    else:
        print("Strong evidence for Null Hypothesis")
        print("Accept Null Hypothesis - Data is not Stationary")
        print("Data is NOT Stationary for", title)

# %%
test_adf(df['Close'], 'Stock Close Price')
# Out:
# Strong evidence for Null Hypothesis
# Accept Null Hypothesis - Data is not Stationary
# Data is NOT Stationary for Stock Close Price

# %%
"""
The Close price is not stationary. 
Therefore, differencing needs to be performed
"""
test_adf(df['Close'].diff(), 'Stock Close Price - First Difference')
# Out:
# Strong evidence against Null Hypothesis
# Reject Null Hypothesis - Data is Stationary
# Data is Stationary Stock Close Price - First Difference

# %% [markdown]
# ### Plot ACF (Autocorrelation) and PACF (Partial Autocorrelation)

# %%
fig, ax = plt.subplots(2,1, figsize=(10,5))

fig = sm.tsa.graphics.plot_acf(df['Close'], lags=50, ax=ax[0])

fig = sm.tsa.graphics.plot_pacf(df['Close'], lags=50, ax=ax[1])
plt.show()
# Out:
# C:\Python310\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ## Build the SARIMAX model

# %% [markdown]
# ### Use auto_arima to determine the optimal p,d,q orders
# We can determine p,d,q orders by using ACF and PACF plots above. However, a stepwise search will enable us to try out more optimal p,d,q orders.

# %%
from pmdarima.arima import auto_arima

# %%
step_wise_exog = auto_arima(train_labels, exogenous= train_features,
                           start_p=1, start_q=1, 
                           max_p=7, max_q=7, 
                           d=None, D=1, test='adf', max_d=7, seasonal=True, m=5,
                           trace=True, 
                           error_action='ignore', 
                           suppress_warnings=True,
                           stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,1,1)[5] intercept   : AIC=inf, Time=2.45 sec
#  ARIMA(0,0,0)(0,1,0)[5] intercept   : AIC=-2021.228, Time=0.14 sec
#  ARIMA(1,0,0)(1,1,0)[5] intercept   : AIC=-4529.520, Time=0.77 sec
#  ARIMA(0,0,1)(0,1,1)[5] intercept   : AIC=-3242.793, Time=0.68 sec
#  ARIMA(0,0,0)(0,1,0)[5]             : AIC=-2019.815, Time=0.06 sec
#  ARIMA(1,0,0)(0,1,0)[5] intercept   : AIC=-3991.261, Time=0.52 sec
#  ARIMA(1,0,0)(2,1,0)[5] intercept   : AIC=-4674.409, Time=1.39 sec
#  ARIMA(1,0,0)(2,1,1)[5] intercept   : AIC=inf, Time=5.41 sec
#  ARIMA(1,0,0)(1,1,1)[5] intercept   : AIC=inf, Time=2.35 sec
#  ARIMA(0,0,0)(2,1,0)[5] intercept   : AIC=-2028.501, Time=0.91 sec
#  ARIMA(2,0,0)(2,1,0)[5] intercept   : AIC=-4677.922, Time=2.63 sec
#  ARIMA(2,0,0)(1,1,0)[5] intercept   : AIC=-4532.396, Time=1.09 sec
#  ARIMA(2,0,0)(2,1,1)[5] intercept   : AIC=inf, Time=4.26 sec
#  ARIMA(2,0,0)(1,1,1)[5] intercept   : AIC=inf, Time=2.28 sec
#  ARIMA(3,0,0)(2,1,0)[5] intercept   : AIC=-4678.218, Time=4.41 sec
#  ARIMA(3,0,0)(1,1,0)[5] intercept   : AIC=-4537.949, Time=2.22 sec
#  ARIMA(3,0,0)(2,1,1)[5] intercept   : AIC=inf, Time=5.08 sec
#  ARIMA(3,0,0)(1,1,1)[5] intercept   : AIC=inf, Time=2.77 sec
#  ARIMA(4,0,0)(2,1,0)[5] intercept   : AIC=-4680.049, Time=6.02 sec
#  ARIMA(4,0,0)(1,1,0)[5] intercept   : AIC=-4540.643, Time=2.64 sec
#  ARIMA(4,0,0)(2,1,1)[5] intercept   : AIC=inf, Time=6.30 sec
#  ARIMA(4,0,0)(1,1,1)[5] intercept   : AIC=inf, Time=3.53 sec
#  ARIMA(4,0,1)(2,1,0)[5] intercept   : AIC=-4674.405, Time=6.59 sec
#  ARIMA(3,0,1)(2,1,0)[5] intercept   : AIC=-4675.213, Time=3.61 sec
#  ARIMA(4,0,0)(2,1,0)[5]             : AIC=-4681.585, Time=1.39 sec
#  ARIMA(4,0,0)(1,1,0)[5]             : AIC=-4542.151, Time=0.92 sec
#  ARIMA(4,0,0)(2,1,1)[5]             : AIC=inf, Time=4.41 sec
#  ARIMA(4,0,0)(1,1,1)[5]             : AIC=inf, Time=3.56 sec
#  ARIMA(3,0,0)(2,1,0)[5]             : AIC=-4679.799, Time=1.10 sec
#  ARIMA(4,0,1)(2,1,0)[5]             : AIC=-4679.926, Time=2.21 sec
#  ARIMA(3,0,1)(2,1,0)[5]             : AIC=-4676.959, Time=2.27 sec
#
# Best model:  ARIMA(4,0,0)(2,1,0)[5]
# Total fit time: 83.979 seconds

# %%
step_wise_exog.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                 1967
# Model:             SARIMAX(4, 0, 0)x(2, 1, 0, 5)   Log Likelihood                2347.792
# Date:                           Mon, 21 Nov 2022   AIC                          -4681.585
# Time:                                   16:03:41   BIC                          -4642.513
# Sample:                                        0   HQIC                         -4667.224
#                                           - 1967
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9597      0.016     60.630      0.000       0.929       0.991
# ar.L2         -0.0211      0.024     -0.887      0.375      -0.068       0.026
# ar.L3          0.0083      0.026      0.318      0.750      -0.043       0.059
# ar.L4         -0.0441      0.020     -2.251      0.024      -0.083      -0.006
# ar.S.L5       -0.6526      0.019    -34.004      0.000      -0.690      -0.615
# ar.S.L10      -0.2766      0.019    -14.331      0.000      -0.314      -0.239
# sigma2         0.0053   9.48e-05     56.301      0.000       0.005       0.006
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              1895.56
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.85   Skew:                             0.14
# Prob(H) (two-sided):                  0.04   Kurtosis:                         7.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
step_wise_exog.plot_diagnostics(figsize=(15,12));

# %% [markdown]
# ### Fit the SARIMAX model using the best p,d,q orders

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_exog = SARIMAX(train_labels, exog=train_features,
                order=(4,0,0), seasonal_order=(2,1,0,5),
                enforce_invertibility=True, enforce_stationarity=True)
# Out:
# C:\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
results = model_exog.fit()
# Out:
# C:\Python310\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                             Close   No. Observations:                 1967
# Model:             SARIMAX(4, 0, 0)x(2, 1, 0, 5)   Log Likelihood                2357.653
# Date:                           Mon, 21 Nov 2022   AIC                          -4679.306
# Time:                                   16:03:54   BIC                          -4578.835
# Sample:                                        0   HQIC                         -4642.379
#                                           - 1967
# Covariance Type:                             opg
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# 7 DAYS MA          0.6960      0.170      4.090      0.000       0.362       1.029
# 7 DAYS STD DEV     0.0043      0.004      1.153      0.249      -0.003       0.012
# 14 DAYS MA        -0.0158      0.184     -0.086      0.932      -0.377       0.345
# 21 DAYS MA        -0.2165      0.131     -1.650      0.099      -0.474       0.041
# dayofweek         -0.0015      0.002     -0.784      0.433      -0.005       0.002
# quarter            0.0018      0.019      0.094      0.925      -0.035       0.038
# month              1.3385      0.811      1.649      0.099      -0.252       2.929
# year              -0.3580      0.519     -0.690      0.490      -1.375       0.659
# dayofyear         -1.3829      0.817     -1.693      0.090      -2.984       0.218
# dayofmonth         0.1094      0.067      1.623      0.105      -0.023       0.241
# weekofyear        -0.0022      0.010     -0.213      0.831      -0.022       0.018
# ar.L1              0.8570      0.024     36.197      0.000       0.811       0.903
# ar.L2             -0.0383      0.025     -1.529      0.126      -0.087       0.011
# ar.L3              0.0008      0.027      0.029      0.977      -0.052       0.053
# ar.L4             -0.0511      0.026     -1.960      0.050      -0.102   -2.81e-06
# ar.S.L5           -0.6793      0.021    -32.042      0.000      -0.721      -0.638
# ar.S.L10          -0.2794      0.020    -13.724      0.000      -0.319      -0.240
# sigma2             0.0053      0.000     52.663      0.000       0.005       0.005
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):              1835.82
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.87   Skew:                             0.12
# Prob(H) (two-sided):                  0.07   Kurtosis:                         7.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### Predictions

# %%
predictions = results.predict(start=train_len, end=len(df)-1, exog=test_features)
# Out:
# C:\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
actual_close = df[['Close']]
act = pd.DataFrame(actual_close.iloc[train_len:, 0])

# %%
predictions = pd.DataFrame(predictions)
predictions.reset_index(drop=True, inplace=True)
predictions.index = test_features.index
predictions['Actual'] = act['Close']
predictions.rename(columns={'predicted_mean':'Pred'}, inplace=True)

# %%
predictions
# Out:
#                 Pred    Actual
# Date
# 2020-09-10 -1.545811 -1.621981
# 2020-09-11 -1.561033 -1.516806
# 2020-09-14 -1.574282 -1.510619
# 2020-09-15 -1.566383 -1.566300
# 2020-09-16 -1.554686 -1.566300
# ...              ...       ...
# 2022-09-12 -0.398491  1.545664
# 2022-09-13 -0.387610  1.607532
# 2022-09-14 -0.364588  1.499263
# 2022-09-15 -0.359586  1.530197
# 2022-09-16 -0.372564  1.452862
#
# [492 rows x 2 columns]

# %%
predictions['Actual'].plot(figsize=(20,8), legend=True, color='blue')
predictions['Pred'].plot(legend=True, color='red', figsize=(20,8))
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# ### Evaluation

# %%
from joblib import load

# %%
close_scaler = load('../feature_engineering/isat_close_scaler.bin')

# %%
inversed_pred = close_scaler.inverse_transform(np.array(predictions['Pred']).reshape(-1,1))
inversed_act = close_scaler.inverse_transform(np.array(predictions['Actual']).reshape(-1,1))

# %%
inversed = pd.DataFrame(inversed_pred)
inversed['Actual'] = inversed_act
inversed.rename({0:'Pred'}, axis=1, inplace=True)
inversed.index = test_labels.index
inversed.head(2)
# Out:
#                    Pred  Actual
# Date
# 2020-09-10  2203.118125  2080.0
# 2020-09-11  2178.513584  2250.0

# %% [markdown]
# **Plot Error Distribution**

# %%
def plotErrorHist(inversed_df):
    """
    Function to plot error histogram
    """
    error = inversed_df['Pred'] - inversed_df['Actual']
    plt.hist(error, bins=25)
    plt.xlabel('Prediction Error [Close]')
    _ = plt.ylabel('Count')

# %%
plotErrorHist(inversed)

# %% [markdown]
# **RMSE**

# %%
from statsmodels.tools.eval_measures import rmse

# %%
rmse(inversed['Pred'], inversed['Actual'])
# Out:
# 2241.0281504293366

# %% [markdown]
# **MAPE**

# %%
# mape
def mape(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
mape(inversed['Actual'], inversed['Pred'])
# Out:
# 33.27829935456072

# %% [markdown]
# **R-squared**

# %%
from sklearn.metrics import r2_score

# %%
r2_score(inversed['Actual'], inversed['Pred'])
# Out:
# -1.2198465258876916

# %% [markdown]
# ### Save the model

# %%
from joblib import dump, load
dump(results, './models/isat.joblib')
# Out:
# ['./models/isat.joblib']

# %%
loaded = load('./models/isat.joblib')
loaded.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                             Close   No. Observations:                 1967
# Model:             SARIMAX(4, 0, 0)x(2, 1, 0, 5)   Log Likelihood                2357.653
# Date:                           Mon, 21 Nov 2022   AIC                          -4679.306
# Time:                                   16:03:55   BIC                          -4578.835
# Sample:                                        0   HQIC                         -4642.379
#                                           - 1967
# Covariance Type:                             opg
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# 7 DAYS MA          0.6960      0.170      4.090      0.000       0.362       1.029
# 7 DAYS STD DEV     0.0043      0.004      1.153      0.249      -0.003       0.012
# 14 DAYS MA        -0.0158      0.184     -0.086      0.932      -0.377       0.345
# 21 DAYS MA        -0.2165      0.131     -1.650      0.099      -0.474       0.041
# dayofweek         -0.0015      0.002     -0.784      0.433      -0.005       0.002
# quarter            0.0018      0.019      0.094      0.925      -0.035       0.038
# month              1.3385      0.811      1.649      0.099      -0.252       2.929
# year              -0.3580      0.519     -0.690      0.490      -1.375       0.659
# dayofyear         -1.3829      0.817     -1.693      0.090      -2.984       0.218
# dayofmonth         0.1094      0.067      1.623      0.105      -0.023       0.241
# weekofyear        -0.0022      0.010     -0.213      0.831      -0.022       0.018
# ar.L1              0.8570      0.024     36.197      0.000       0.811       0.903
# ar.L2             -0.0383      0.025     -1.529      0.126      -0.087       0.011
# ar.L3              0.0008      0.027      0.029      0.977      -0.052       0.053
# ar.L4             -0.0511      0.026     -1.960      0.050      -0.102   -2.81e-06
# ar.S.L5           -0.6793      0.021    -32.042      0.000      -0.721      -0.638
# ar.S.L10          -0.2794      0.020    -13.724      0.000      -0.319      -0.240
# sigma2             0.0053      0.000     52.663      0.000       0.005       0.005
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):              1835.82
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.87   Skew:                             0.12
# Prob(H) (two-sided):                  0.07   Kurtosis:                         7.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
